# %% [markdown]
# # Analiza danych-opis

# %% [markdown]
# Wczytanie danych:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
ae = pd.read_csv('app_events.csv')
al = pd.read_csv('app_labels.csv')
ev = pd.read_csv('events.csv')
lc = pd.read_csv('label_categories.csv')
pb = pd.read_csv('phone_brand_device_model.csv')
tr = pd.read_csv('gender_age_train.csv')

# %%
Wszystkie cechy:
    phone_brand_device_model.csv : ['device_id' 'phone_brand' 'device_model']
    label_categories.csv : ['label_id' 'category']
    events.csv : ['event_id' 'device_id' 'timestamp' 'longitude' 'latitude']
    app_labels.csv : ['app_id' 'label_id']
    app_events.csv : ['event_id' 'app_id' 'is_installed' 'is_active']
        
    unikalne: ['device_id' 'phone_brand' 'device_model' 'label_id' 'category' 'event_id' 'device_id' 
                         'timestamp' 'longitude' 'latitude' 'is_installed' 'is_active']
# Out:
#   File "<ipython-input-29-7be4b52de0ea>", line 1
#     Wszystkie cechy:
#                   ^
# SyntaxError: invalid syntax

# %%
#phone_brand_device_model.csv unikalne
print('\nLiczba obserwacji:\n', pb.count())
# Out:
# Liczba obserwacji:
#  device_id       187245
# phone_brand     187244
# device_model    187245
# dtype: int64

# %%
#phone_brand_device_model.csv NaN
print('\nLiczba obserwacji:\n', pb.isnull().sum())
# Out:
# Liczba obserwacji:
#  device_id       0
# phone_brand     1
# device_model    0
# dtype: int64

# %%
#label_categories.csv unikalne
print('\nLiczba obserwacji:\n', lc.count())
# Out:
# Liczba obserwacji:
#  label_id    930
# category    927
# dtype: int64

# %%
#label_categories.csv NaN
print('\nLiczba obserwacji:\n', lc.isnull().sum())
# Out:
# Liczba obserwacji:
#  label_id    0
# category    3
# dtype: int64

# %%
#events.csv unikalne
print('\nLiczba obserwacji:\n', ev.count())
# Out:
# Liczba obserwacji:
#  event_id     3252950
# device_id    3252950
# timestamp    3252950
# longitude    3252950
# latitude     3252950
# dtype: int64

# %%
#events.csv NaN
print('\nLiczba obserwacji:\n', ev.isnull().sum())
# Out:
# Liczba obserwacji:
#  event_id     0
# device_id    0
# timestamp    0
# longitude    0
# latitude     0
# dtype: int64

# %%
#app_labels.csv unikalne
print('\nLiczba obserwacji:\n', al.count())
# Out:
# Liczba obserwacji:
#  app_id      459943
# label_id    459943
# dtype: int64

# %%
#app_labels.csv NaN
print('\nLiczba obserwacji:\n', al.isnull().sum())
# Out:
# Liczba obserwacji:
#  app_id      0
# label_id    0
# dtype: int64

# %%
#app_events.csv unikalne
print('\nLiczba obserwacji:\n', ae.count())
# Out:
# Liczba obserwacji:
#  event_id        32473067
# app_id          32473067
# is_installed    32473067
# is_active       32473067
# dtype: int64

# %%
#app_events.csv NaN
print('\nLiczba obserwacji:\n', ae.isnull().sum())
# Out:
# Liczba obserwacji:
#  event_id        0
# app_id          0
# is_installed    0
# is_active       0
# dtype: int64

# %% [markdown]
# Cechy w których występują puste elementy:
# -category w label_categories -PROPONUJE zastąpić unknown bo tego jest najwiecej tj.26 a drugi co ma najwiecej jest 3
# -phone_brand w phone_brand_device_model -PROPONUJE xiaomi bo tez najwiecej

# %%
z=lc.groupby('category')['label_id']
print(z.nunique().sort_values(ascending=False))
# Out:
# category
# unknown                                                                  26
# the film                                                                  3
# Pay                                                                       3
# Lottery ticket                                                            3
# Science and Technology                                                    3
# health                                                                    3
# Insurance                                                                 3
# music                                                                     3
# Financial Information                                                     3
# quality                                                                   2
# financial                                                                 2
# navigation                                                                2
# ...

# %%
print(pb.groupby('phone_brand').size().sort_values(ascending=False))
# Out:
# phone_brand
# xiaomi     43209
# samsung    34286
# huawei     32564
# vivo       14395
# OPPO       14289
# meizu      11853
# coolpad     8407
# lenovo      6761
# gionee      2768
# HTC         2682
# zte         2096
# Ishi        1930
# sony        1821
# nubia       1144
# LG           763
# ccmc         671
# TCL          586
# dowe         544
# hammer       535
# youmi        492
# hisense      489
# oneplus      438
# yuxin        396
# qiku         378
# Ktouch       376
# koobee       317
# moto         228
# ZUK          153
# meitu        151
# asus         141
#            ...
# 智镁             5
# mole           5
# 天宏时代           4
# 唯比             4
# 宝捷讯            4
# 本为             4
# 惠普             4
# 鲜米             3
# 丰米             3
# 大显             3
# fs             2
# 赛博宇华           2
# 凯利通            2
# 原点             2
# 世纪星            2
# 恒宇丰            2
# 戴尔             2
# MIL            2
# 极米             1
# 西门子            1
# 碟米             1
# ...

# %%
df = pd.DataFrame.from_csv('events.csv')

# %%
df.plot.scatter(x='longitude', y='latitude')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
#phone_brand_device_model.csv unikalne
ae.nunique()
# Out:
# event_id        1488096
# app_id            19237
# is_installed          1
# is_active             2
# dtype: int64

# %%
#label_categories.csv unikalne
lc.nunique()
# Out:
# label_id    930
# category    835
# dtype: int64

# %%
#events.csv unikalne
ev.nunique()
# Out:
# event_id     3252950
# device_id      60865
# timestamp     588125
# longitude       3588
# latitude        3086
# dtype: int64

# %%
#app_labels.csv unikalne
al.nunique()
# Out:
# app_id      113211
# label_id       507
# dtype: int64

# %%
#app_events.csv unikalne
ae.nunique()
# Out:
# event_id        1488096
# app_id            19237
# is_installed          1
# is_active             2
# dtype: int64
